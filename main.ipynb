# %%
import numpy as np
import pandas as pd
import math
import librosa
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime
from IPython.display import Image

# %%
df1 = pd.read_csv('echonest.csv')
df2 = pd.read_csv('features.csv')
df3 = pd.read_csv('tracks.csv')

# %% [markdown]
# # 2.1

# %% [markdown]
# I look up information in datasets

# %%
df1
# Out:
#        track_id  audio_features_acousticness  audio_features_danceability  \
# 0             2                     0.416675                     0.675894
# 1             3                     0.374408                     0.528643
# 2             5                     0.043567                     0.745566
# 3            10                     0.951670                     0.658179
# 4           134                     0.452217                     0.513238
# ...         ...                          ...                          ...
# 13124    124857                     0.007592                     0.790364
# 13125    124862                     0.041498                     0.843077
# 13126    124863                     0.000124                     0.609686
# 13127    124864                     0.327576                     0.574426
# 13128    124911                     0.993606                     0.499339
#
#        audio_features_energy  audio_features_instrumentalness  \
# ...

# %%
df2
# Out:
#         track_id  chroma_cens_kurtosis_01  chroma_cens_kurtosis_02  \
# 0              2                 7.180653                 5.230309
# 1              3                 1.888963                 0.760539
# 2              5                 0.527563                -0.077654
# 3             10                 3.702245                -0.291193
# 4             20                -0.193837                -0.198527
# ...          ...                      ...                      ...
# 106569    155316                -0.490129                 0.463834
# 106570    155317                -0.461559                -0.229601
# 106571    155318                 0.552473                -0.110498
# 106572    155319                -0.176901                 0.187208
# 106573    155320                 0.489665                 1.862421
#
#         chroma_cens_kurtosis_03  chroma_cens_kurtosis_04  \
# 0                      0.249321                 1.347620
# ...

# %%
df3
# Out:
#         track_id  album_comments   album_date_created  album_date_released  \
# 0              2               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 1              3               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 2              5               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 3             10               0  2008-11-26 01:45:08  2008-02-06 00:00:00
# 4             20               0  2008-11-26 01:45:05  2009-01-06 00:00:00
# ...          ...             ...                  ...                  ...
# 106569    155316               0  2017-03-30 15:20:35  2017-02-17 00:00:00
# 106570    155317               0  2017-03-30 15:20:35  2017-02-17 00:00:00
# 106571    155318               0  2017-03-30 15:20:35  2017-02-17 00:00:00
# 106572    155319               0  2017-03-30 15:20:35  2017-02-17 00:00:00
# 106573    155320               0  2017-03-26 16:22:18  2017-03-26 00:00:00
#
#        album_engineer  album_favorites  album_id  \
# ...

# %% [markdown]
# Merge df1 df2 df3 by key_id:track_id

# %%
df = pd.merge(df2, df1, on="track_id", how="right")

# %%
df= pd.merge(df3, df, on="track_id", how="right")

# %% [markdown]
# Get dataset which content~13k rows

# %%
df
# Out:
#        track_id  album_comments   album_date_created  album_date_released  \
# 0             2               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 1             3               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 2             5               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 3            10               0  2008-11-26 01:45:08  2008-02-06 00:00:00
# 4           134               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# ...         ...             ...                  ...                  ...
# 13124    124857               0  2015-09-09 14:39:58  2006-02-06 00:00:00
# 13125    124862               0  2015-09-09 14:39:58  2006-02-06 00:00:00
# 13126    124863               0  2015-09-09 14:39:58  2006-02-06 00:00:00
# 13127    124864               0  2015-09-09 14:39:58  2006-02-06 00:00:00
# 13128    124911               0  2015-09-11 12:08:44  2010-09-23 00:00:00
#
#       album_engineer  album_favorites  album_id  \
# ...

# %% [markdown]
# Use basic pandas tools to understand new df

# %%
df.tail()
# Out:
#        track_id  album_comments   album_date_created  album_date_released  \
# 13124    124857               0  2015-09-09 14:39:58  2006-02-06 00:00:00
# 13125    124862               0  2015-09-09 14:39:58  2006-02-06 00:00:00
# 13126    124863               0  2015-09-09 14:39:58  2006-02-06 00:00:00
# 13127    124864               0  2015-09-09 14:39:58  2006-02-06 00:00:00
# 13128    124911               0  2015-09-11 12:08:44  2010-09-23 00:00:00
#
#       album_engineer  album_favorites  album_id  \
# 13124  Daan Hendriks                0     18862
# 13125  Daan Hendriks                0     18862
# 13126  Daan Hendriks                0     18862
# 13127  Daan Hendriks                0     18862
# 13128            NaN                0     18873
#
#                                        album_information  album_listens  \
# 13124  <p>"Do you know a word that means both look at...          55904
# 13125  <p>"Do you know a word that means both look at...          55904
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13129 entries, 0 to 13128
# Columns: 820 entries, track_id to temporal_features_223
# dtypes: float64(764), int64(16), object(40)
# memory usage: 82.2+ MB

# %%
df.describe()
# Out:
#             track_id  album_comments  album_favorites      album_id  \
# count   13129.000000    13129.000000     13129.000000  13129.000000
# mean    34031.058268        0.348770         1.670805   6434.838982
# std     28950.422182        1.186648         3.073932   4513.861075
# min         2.000000       -1.000000        -1.000000      1.000000
# 25%     12986.000000        0.000000         0.000000   3036.000000
# 50%     28097.000000        0.000000         1.000000   5972.000000
# 75%     45021.000000        0.000000         2.000000   8697.000000
# max    124911.000000       17.000000        40.000000  18873.000000
#
#        album_listens  album_tracks  artist_comments  artist_favorites  \
# count   13129.000000  13129.000000     13129.000000      13129.000000
# mean    21288.982710     12.406505         1.546119         19.630589
# std     52361.334813     12.093782         4.958391         66.047980
# min        -1.000000     -1.000000        -1.000000         -1.000000
# ...

# %% [markdown]
# Change df to csv and xlsx, to see every column info

# %%
df.to_csv('df.csv', index=False)

# %%
df.to_excel('df.xlsx')

# %%
from IPython.display import Image
Image('df_xlsx.png')

# %% [markdown]
# Check columns for isnull()

# %%
df.isnull().sum()
# Out:
# track_id                     0
# album_comments               0
# album_date_created         191
# album_date_released       3817
# album_engineer           10226
#                          ...
# temporal_features_219        0
# temporal_features_220        0
# temporal_features_221        0
# temporal_features_222        0
# temporal_features_223        0
# Length: 820, dtype: int64

# %%
null_column_count=0
null_list=df.isnull().sum()
for i in range(len(null_list)):
        if(null_list[i]!=0):
            null_column_count+=1
            print(i)
print("null_column_count:",null_column_count)
# Out:
# 2
# 3
# 4
# 7
# 9
# 13
# 14
# 15
# 16
# 17
# 19
# 22
# 23
# 24
# 25
# 27
# 29
# 30
# 35
# 37
# 40
# 43
# 45
# 46
# 48
# 50
# 52
# 579
# 580
# 581
# 582
# 583
# 586
# 587
# 588
# 589
# 590
# null_column_count: 37

# %% [markdown]
# Check columns for duplicates

# %%
df = df.loc[:,~df.columns.duplicated()]

# %%
df
# Out:
#        track_id  album_comments   album_date_created  album_date_released  \
# 0             2               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 1             3               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 2             5               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 3            10               0  2008-11-26 01:45:08  2008-02-06 00:00:00
# 4           134               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# ...         ...             ...                  ...                  ...
# 13124    124857               0  2015-09-09 14:39:58  2006-02-06 00:00:00
# 13125    124862               0  2015-09-09 14:39:58  2006-02-06 00:00:00
# 13126    124863               0  2015-09-09 14:39:58  2006-02-06 00:00:00
# 13127    124864               0  2015-09-09 14:39:58  2006-02-06 00:00:00
# 13128    124911               0  2015-09-11 12:08:44  2010-09-23 00:00:00
#
#       album_engineer  album_favorites  album_id  \
# ...

# %% [markdown]
# # 2.2

# %% [markdown]
# #Methods of reduce dimensiolity
#
# Principal Component Analysis, Multiple Correspondence Analysis, Singular Value Decomposition, Factor Analysis for Mixed Data, Two-Steps clustering

# %% [markdown]
# HINT: We don't want to miss relevant variables like song's duration, language, etc., after the dimensionality reduction. To keep those variables, you can apply the dimensionality reduction method(s) on features coming from the same file. Later you can stack them with the variables selected from another file.

# %% [markdown]
# MAIN:Apply the selected method(s) to your data. Make sure that the chosen method retains > 70% of the total variance.

# %% [markdown]
# ### Principal Component Analysis

# %% [markdown]
# https://en.wikipedia.org/wiki/Principal_component_analysis
#
# https://www.youtube.com/watch?v=kApPBm1YsqU&ab_channel=MichaelGalarnyk
#
# https://www.youtube.com/watch?v=Lsue2gEM9D0&ab_channel=StatQuestwithJoshStarmer

# %% [markdown]
# ### Multiple Correspondence Analysis

# %% [markdown]
# https://www.youtube.com/watch?v=aZAn0rjJWQc&ab_channel=StatisticsNinja
#
# https://www.youtube.com/watch?v=gZ_7WWEVlTg&ab_channel=Fran%C3%A7oisHusson

# %% [markdown]
# ### Singular Value Decomposition

# %% [markdown]
# https://www.youtube.com/watch?v=gXbThCXjZFM&ab_channel=SteveBrunton
#
# https://www.youtube.com/watch?v=mBcLRGuAFUk&ab_channel=MITOpenCourseWare
#
# https://www.youtube.com/watch?v=pcUPelQ5bMM&ab_channel=TheEngineeringWorld

# %% [markdown]
# ### Factor Analysis for Mixed Data

# %% [markdown]
# Аружан

# %% [markdown]
# ### Two-Steps clustering

# %% [markdown]
# Аружан
